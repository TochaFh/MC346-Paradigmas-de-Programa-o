# %% [markdown]
# # Estruturas e Abstrações em Scheme

# %% [markdown]
# ## Lista Imprópria
#
# não termina com lista vazia
#
# `x -> y`

# %%
'(x . y)
# Out:
# (x . y)

# %%
(cons 'x 'y)
# Out:
# (x . y)

# %% [markdown]
# ## Lista Adequada (Proper List)

# %%
'( x . () )
# Out:
# (x)

# %%
(cons 'x '())
# Out:
# (x)

# %%
'( x . (y . () ) )
# Out:
# (x y)

# %%
( cons 'x (cons 'y '() ) )
# Out:
# (x y)

# %%
'(x y)
# Out:
# (x y)

# %% [markdown]
# ## Exercício 1
#
# Indique o que acontecerá em cada um dos exemplos abaixo (sem executá-los).
#
# ```scheme
# (car '(x . y))
# (cdr '(x . y))
# ```

# %% [markdown]
# > resposta
# > O car retorna o elemento x.
# > O cdr retorna uma lista (. y).

# %% [markdown]
# ### `.` nos argumentos de função

# %%
(define (soma a b)
  (+ a b))

# %%
(+ 3 4)
# Out:
# 7

# %%
(define (como-lista args )
  args )

# %%
(como-lista '(3 4 5) )
# Out:
# (3 4 5)

# %%
(define (transforma-lista . args)
  args)

# %%
(transforma-lista 3 4 5)
# Out:
# (3 4 5)

# %%
(define (monta primeiro segundo . resto)
  (list primeiro segundo resto)
  )

# %%
(monta 5 7 8 9)
# Out:
# (5 7 (8 9))

# %% [markdown]
# ## Exercício 2
#
# Escreva uma função `increment` que receba como parâmetro um número `X` e uma sequência de outros números `Ys` (não em forma de lista, mas como argumentos depois de `X`).
#
# A função deve retornar uma lista com todos os `Ys` incrementados com o valor de `X`.
#
# Entrada:
# ```scheme
# (increment x y1 y2 y3 ...)
# ```
#
# Saída:
# ```scheme
# (y1+x y2+x y3+x ...)
# ```

# %%
(define (increment x . Ys)
  (map (lambda (y) (+ y x)) Ys)
)

(increment 10 1 2 3 4 5)
# Out:
# (31 32 33 34 35)

# %% [markdown]
# ## Usando o `apply` para recursão com `.`

# %%
(+ 5 7 3 2)
# Out:
# 17

# %%
(apply + '(5 7 3 2))
# Out:
# 17

# %% [markdown]
# ## Exercício 3
#
# Sem executá-la, diga o que acontecerá quando aplicada a função `generate`.
#
# ```scheme
# (define (generate repetition . list)
#   (if (<= repetition 0)
#       '()
#       (cons list (apply generate (- repetition 1) list))
#       )
#   )
#
# (generate 3 8 9 10)
# ```

# %% [markdown]
# > resposta
# > Retornará uma lista de listas repetidas (repetition vezes) com os valores passados.

# %% [markdown]
# ## Listas de Associação

# %%
(define dinossauros-a
  '((espinossauro . carnívoro)
    (paquicefalossauro . herbívoro)
    (triceratops . herbívoro)))

# %% [markdown]
# ## Exercício 4
#
# Por que é conveniente usar `dot` nesta lista de associação?

# %% [markdown]
# > resposta
# > Com as listas impróprias a partir do dot, podemos usar o cdr para obter o valor (elemento) diretamente das "propriedades" dos dinossauros.

# %% [markdown]
# ### Lista de Associação - Múltiplos Valores

# %%
(define dinossauros-b
  '((espinossauro . (carnívoro terópode))
    (paquicefalossauro . (herbívoro marginocefália))
    (triceratops . (herbívoro ceratopsídeo))))
dinossauros-b
# Out:
# ((espinossauro carnívoro terópode) (paquicefalossauro herbívoro marginocefália) (triceratops herbívoro ceratopsídeo))

# %%
(car '(paquicefalossauro . (herbívoro marginocefália)))
# Out:
# paquicefalossauro

# %%
(cdr '(paquicefalossauro . (herbívoro marginocefália)))
# Out:
# (herbívoro marginocefália)

# %%
(define dinossauros-c
  '((espinossauro carnívoro terópode)
    (paquicefalossauro herbívoro marginocefália)
    (triceratops herbívoro ceratopsídeo)))

# %%
(car '(paquicefalossauro herbívoro marginocefália))
# Out:
# paquicefalossauro

# %%
(cdr '(paquicefalossauro herbívoro marginocefália))
# Out:
# (herbívoro marginocefália)

# %% [markdown]
# ## `assq`

# %%
(assq 'paquicefalossauro dinossauros-a)
# Out:
# (paquicefalossauro . herbívoro)

# %%
(assq 'ornitorrinco dinossauros-a)
# Out:
# #f

# %%
(cdr (assq 'paquicefalossauro dinossauros-a))
# Out:
# herbívoro

# %%
(assq 'paquicefalossauro dinossauros-b)
# Out:
# (paquicefalossauro herbívoro marginocefália)

# %%
(assq 'paquicefalossauro dinossauros-c)
# Out:
# (paquicefalossauro herbívoro marginocefália)

# %% [markdown]
# ## `list-ref`

# %%
(list-ref '("Tyrannosaurus Rex" dinosaur Cretaceous 12.0 carnivore) 2)
# Out:
# Cretaceous

# %%
(list-ref '("Tyrannosaurus Rex" dinosaur Cretaceous 12.0 carnivore) 5)
# Out:
# out-of-range
# (list-ref Argument ~A out of range: ~S (2 5) (5))

# %%
(define prehistoric-schema
  '((name . 0) (type . 1) (period . 2) (length . 3) (diet . 4)))

# %%
(assq 'type prehistoric-schema)
# Out:
# (type . 1)

# %%
(cdr (assq 'period prehistoric-schema))
# Out:
# 2

# %%
(list-ref '("Tyrannosaurus Rex" "dinosaur" "Cretaceous" 12.0 "carnivore") 2)
# Out:
# "Cretaceous"

# %% [markdown]
# # Criando Primitivas SQL-like

# %% [markdown]
# ## Criando um Lista de Associação
#
# A lista representa o esquema de um conjunto de dados.

# %%
(define prehistoric-schema
  '((name . 0) (type . 1) (period . 2) (size . 3) (diet . 4)))

# %% [markdown]
# ## `assq`

# %%
(assq 'type prehistoric-schema)
# Out:
# (type . 1)

# %%
(cdr (assq 'period prehistoric-schema))
# Out:
# 2

# %% [markdown]
# ## `list-ref`

# %%
(define prehistoric-record '("Tyrannosaurus Rex" dinosaur Cretaceous 12.0 carnivore))

# %%
(list-ref prehistoric-record 2)
# Out:
# Cretaceous

# %% [markdown]
# ## Exercício 5
#
# Dadas as listas prehistoric-schema, representando um esquema de uma tabela (nomes de colunas e posições), e prehistoric-record, representando o registro de uma tabela. Escreva uma função project-1 que receba essas duas listas como parâmetros, mais o nome de uma coluna, e retorne o valor desta coluna no registro.
#
# ```scheme
# (project-1 prehistoric-schema prehistoric-record 'period)
# ```
#
# Deve retornar:
# ```
# Cretaceous
# ```

# %%
(define prehistoric-schema
  '((name . 0) (type . 1) (period . 2) (size . 3) (diet . 4)))

(define prehistoric-record '("Tyrannosaurus Rex" dinosaur Cretaceous 12.0 carnivore))

(define (project-1 schema record key)
  (list-ref record (cdr(assq key schema)))
)

(project-1 prehistoric-schema prehistoric-record 'period)
# Out:
# Cretaceous

# %% [markdown]
# ## Exercício 6
#
# Considere agora o prehistoric-data com muitos registros (uma lista de listas):
#
# ```scheme
# (define prehistoric-data
#   '(("Tyrannosaurus Rex" dinosaur Cretaceous 12.0 carnivore)
#     ("Triceratops" dinosaur Cretaceous 9.0 herbivore)
#     ("Brachiosaurus" dinosaur Jurassic 25.0 herbivore)))
# ```
#
# Escreva uma função project que faça a projeção de uma coluna, ou seja, receba o prehistoric-schema, o prehistoric-data e o nome de uma coluna, retornando uma lista com o valor desta coluna para todos os registros.
#
# A chamada:
# ```scheme
# (project prehistoric-schema prehistoric-data 'diet)
# ```
#
# Deve retornar:
# `(carnivore herbivore herbivore)`

# %%
(define prehistoric-schema
  '((name . 0) (type . 1) (period . 2) (size . 3) (diet . 4)))

(define prehistoric-data
  '(("Tyrannosaurus Rex" dinosaur Cretaceous 12.0 carnivore)
    ("Triceratops" dinosaur Cretaceous 9.0 herbivore)
    ("Brachiosaurus" dinosaur Jurassic 25.0 herbivore)))

(define (project schema records key)
  (map (lambda (r) (list-ref r (cdr(assq key schema)))) records)
)

(define (projectx schema records key)
  (let ((i (cdr(assq key schema))))
    (map (lambda (r) (list-ref r i)) records)
  )
)

(projectx prehistoric-schema prehistoric-data 'diet)
# Out:
# (carnivore herbivore herbivore)

# %% [markdown]
# ## Usando `iota` para produzir pares `(coluna . posição)` automaticamente

# %%
(iota (length '(name type period length diet)))
# Out:
# (0 1 2 3 4)

# %%
(define (indexed-pairs lst)
  (map cons lst (iota (length lst))))

# %%
(indexed-pairs '(name type period length diet))
# Out:
# ((name . 0) (type . 1) (period . 2) (length . 3) (diet . 4))
